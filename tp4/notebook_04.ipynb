# %% [markdown]
# # Taller Práctico Clase 4: SVM y el Poder de los Kernels
#
# **Objetivo:** En este notebook, aplicaremos los conceptos de Máquinas de Vectores de Soporte (SVM) para resolver un problema de clasificación no lineal. Compararemos el rendimiento de SVM con diferentes kernels frente a un modelo lineal como la Regresión Logística y visualizaremos sus fronteras de decisión para desarrollar una intuición profunda sobre su funcionamiento.
#
# **Temas a cubrir:**
# 1.  Generación y visualización de un dataset no lineal.
# 2.  Entrenamiento de un modelo de Regresión Logística como base.
# 3.  Entrenamiento de SVM con kernel lineal, polinómico y RBF.
# 4.  Visualización interactiva de las fronteras de decisión.
# 5.  Análisis del impacto de los hiperparámetros `C` y `gamma`.

# %% [markdown]
# ## 1. Preparación del Entorno e Importación de Librerías
#
# Primero, importaremos todas las librerías que necesitaremos para nuestro análisis.

# %%
# Manipulación de datos
import numpy as np

# Scikit-Learn para datasets, modelos y preprocesamiento
from sklearn.datasets import make_moons, make_circles, make_blobs
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# Plotly para visualizaciones interactivas
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

# %% [markdown]
# ## 2. Generación y Exploración del Dataset
#
# Para demostrar el poder de los kernels, necesitamos un dataset que no sea linealmente separable. `make_moons` de Scikit-Learn es perfecto para esto, ya que genera dos "medias lunas" entrelazadas.

# %%
# Generamos el dataset
X, y = make_moons(n_samples=500, noise=0.25, random_state=42)

# Dividimos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Escalamos las características. Es una buena práctica para SVM.
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Visualicemos los datos de entrenamiento
fig = px.scatter(x=X_train[:, 0], y=X_train[:, 1], color=y_train.astype(str),
                 color_discrete_map={'0': 'blue', '1': 'red'},
                 title='Dataset de Entrenamiento (Moons)',
                 labels={'x': 'Característica 1', 'y': 'Característica 2'})
fig.update_layout(showlegend=False, height=600, width=800)
fig.show()

# %% [markdown]
# ## 3. Comparación de Modelos y Fronteras de Decisión
#
# Ahora vamos a entrenar nuestros modelos y, para cada uno, visualizaremos la frontera de decisión que aprende. Para ello, crearemos una función auxiliar que nos facilite el ploteo.

# %%
def plot_decision_boundary(model, X, y, title):
    """Función para visualizar la frontera de decisión de un modelo de clasificación en 2D."""
    # Creamos una malla de puntos para evaluar el modelo
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.02),
                         np.arange(y_min, y_max, 0.02))

    # Predecimos sobre cada punto de la malla
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    # Creamos la figura
    fig = go.Figure()

    # Añadimos la superficie de decisión (contour plot)
    fig.add_trace(go.Contour(
        x=xx[0], y=yy[:, 0],
        z=Z, showscale=False,
        colorscale=['rgba(0,0,255,0.2)', 'rgba(255,0,0,0.2)'],
        line_width=0
    ))

    # Añadimos los puntos de datos
    fig.add_trace(go.Scatter(
        x=X[:, 0], y=X[:, 1], mode='markers',
        marker=dict(color=y, colorscale=['blue', 'red'], line=dict(width=1, color='DarkSlateGrey')),
        showlegend=False
    ))

    # Calculamos la precisión (accuracy)
    y_pred = model.predict(X)
    acc = accuracy_score(y, y_pred)

    fig.update_layout(title=f'{title}<br>Accuracy: {acc:.4f}',
                      xaxis_title='Característica 1 (escalada)',
                      yaxis_title='Característica 2 (escalada)',
                      height=600, width=800,)
    return fig

# %% [markdown]
# ### 3.1. Regresión Logística (Modelo Base)

# %%
log_reg = LogisticRegression(random_state=42)
log_reg.fit(X_train, y_train)
fig = plot_decision_boundary(log_reg, X_train, y_train, 'Regresión Logística')
fig.show()

# %% [markdown]
# Como era de esperar, la Regresión Logística intenta separar los datos con una línea recta, fallando en capturar la estructura curva de las "lunas".

# %% [markdown]
# ### 3.2. SVM con Kernel Lineal

# %%
svm_linear = SVC(kernel='linear', random_state=42)
svm_linear.fit(X_train, y_train)
fig = plot_decision_boundary(svm_linear, X_train, y_train, 'SVM con Kernel Lineal')
fig.show()

# %% [markdown]
# El SVM lineal produce un resultado muy similar a la Regresión Logística. Ambos son modelos lineales y, por lo tanto, inadecuados para este problema.

# %% [markdown]
# ### 3.3. SVM con Kernel Polinómico

# %%
svm_poly = SVC(kernel='poly', degree=3, random_state=42)
svm_poly.fit(X_train, y_train)
fig = plot_decision_boundary(svm_poly, X_train, y_train, 'SVM con Kernel Polinómico (grado 3)')
fig.show()

# %% [markdown]
# ¡Mucho mejor! El kernel polinómico puede crear una frontera curva que se adapta mucho mejor a la forma de los datos. La precisión mejora un poco.

# %% [markdown]
# ### 3.4. SVM con Kernel RBF (Radial Basis Function)

# %%
svm_rbf = SVC(kernel='rbf', random_state=42)
svm_rbf.fit(X_train, y_train)
fig = plot_decision_boundary(svm_rbf, X_train, y_train, 'SVM con Kernel RBF')
fig.show()

# %% [markdown]
# El kernel RBF, que es el más flexible y popular, logra la mejor separación. Crea una frontera suave y compleja que se ajusta casi perfectamente a la estructura de los datos, logrando la mayor precisión.

# %% [markdown]
# ## 4. El Impacto de los Hiperparámetros `C` y `gamma`
#
# En SVM, `C` y `gamma` (para el kernel RBF) son cruciales. Vamos a visualizar su efecto.
#
# - **`C` (Parámetro de regularización):** Controla el trade-off entre un margen ancho y clasificar correctamente todos los puntos. Un `C` bajo crea un margen más ancho pero permite más violaciones (más simple, más sesgo). Un `C` alto crea un margen más estrecho, intentando clasificar todo correctamente (más complejo, más varianza).
# - **`gamma`:** Define la influencia de un único ejemplo de entrenamiento. Un `gamma` bajo significa que un punto tiene una influencia lejana (frontera más suave). Un `gamma` alto significa que un punto tiene una influencia muy local (frontera puede ser muy irregular).

# %%
# Creamos una figura con subplots
fig = make_subplots(rows=2, cols=2, subplot_titles=(
    "Bajo Gamma, Bajo C", "Alto Gamma, Bajo C",
    "Bajo Gamma, Alto C", "Alto Gamma, Alto C"
))

hyperparams = [(0.1, 1), (20, 1), (0.1, 2000), (20, 2000)]
plot_positions = [(1, 1), (1, 2), (2, 1), (2, 2)]

for (gamma, C), pos in zip(hyperparams, plot_positions):
    # Entrenar modelo
    svm = SVC(kernel='rbf', gamma=gamma, C=C)
    svm.fit(X_train, y_train)

    # Crear malla
    x_min, x_max = X_train[:, 0].min() - 1, X_train[:, 0].max() + 1
    y_min, y_max = X_train[:, 1].min() - 1, X_train[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.02), np.arange(y_min, y_max, 0.02))

    # Predecir en la malla
    Z = svm.predict(np.c_[xx.ravel(), yy.ravel()]).reshape(xx.shape)

    # Añadir trazas a la sub-figura
    fig.add_trace(go.Contour(x=xx[0], y=yy[:, 0], z=Z, showscale=False, colorscale=['rgba(0,0,255,0.2)', 'rgba(255,0,0,0.2)'], line_width=0), row=pos[0], col=pos[1])
    fig.add_trace(go.Scatter(x=X_train[:, 0], y=X_train[:, 1], mode='markers', marker=dict(color=y_train, colorscale=['blue', 'red'])), row=pos[0], col=pos[1])

fig.update_layout(height=800, width=800, title_text="Efecto de Hiperparámetros C y Gamma en Kernel RBF", showlegend=False)
fig.show()

# %% [markdown]
# ## 5. Desafíos
#
# 1.  **Evaluar en el conjunto de test:** Todos los `accuracy` se calcularon sobre los datos de entrenamiento para visualizar el ajuste. Calcula la precisión de los 4 modelos principales (LogReg, SVM Lineal, Polinómico, RBF con valores por defecto) en el conjunto de `X_test`, `y_test`. ¿Cuál generaliza mejor?
# 2.  **Probar otros datasets:** Importa el dataset de `make_circles` de `sklearn.datasets`. ¿Cómo se comportan los diferentes kernels en este caso? ¿Y con `make_blobs` con 3 centros?
# 3.  **Ajuste fino:** Usando los plots de la sección 4 como guía, intenta encontrar "a mano" una combinación de `C` y `gamma` que te parezca que da el mejor resultado (un buen balance entre ajuste y suavidad de la frontera).

# %%
# Desafio 1
fig = plot_decision_boundary(log_reg, X_test, y_test, 'Regresión Logística')
fig.show()

# %%
fig = plot_decision_boundary(svm_linear, X_test, y_test, 'SVM con Kernel Lineal')
fig.show()

# %%
fig = plot_decision_boundary(svm_poly, X_test, y_test, 'SVM con Kernel Polinómico (grado 3)')
fig.show()

fig = plot_decision_boundary(svm_rbf, X_test, y_test, 'SVM con Kernel RBF')
fig.show()

# %%
# Ejercicio 2
X_circles, y_circles = make_circles(n_samples=1000, noise=0.1, random_state=42)
X_train_circles, X_test_circles, y_train_circles, y_test_circles = train_test_split(X_circles, y_circles, test_size=0.3, random_state=42)

# Escalamos las características
scaler = StandardScaler()
X_train_circles = scaler.fit_transform(X_train_circles)
X_test_circles = scaler.transform(X_test_circles)

# Visualizamos los datos
fig = px.scatter(x=X_train_circles[:, 0], y=X_train_circles[:, 1], color=y_train_circles.astype(str),
                 color_discrete_map={'0': 'blue', '1': 'red'},
                 title='Dataset de Entrenamiento (Círculos)',
                 labels={'x': 'Característica 1', 'y': 'Característica 2'})
fig.show()

# %%
# Regresión Logística
log_reg_circles = LogisticRegression(random_state=42)
log_reg_circles.fit(X_train_circles, y_train_circles)
fig = plot_decision_boundary(log_reg_circles, X_test_circles, y_test_circles, 'Regresión Logística')
fig.show()

# %% [markdown]
# El resultado es muy malo

# %%
# Kernel lineal
svm_linear_circles = SVC(kernel='linear', random_state=42)
svm_linear_circles.fit(X_train_circles, y_train_circles)
fig = plot_decision_boundary(svm_linear_circles, X_test_circles, y_test_circles, 'SVM con Kernel Lineal')
fig.show()

# %%
# Kernel polinómico
svm_poly_circles = SVC(kernel='poly', degree=4, random_state=42)
svm_poly_circles.fit(X_train_circles, y_train_circles)
fig = plot_decision_boundary(svm_poly_circles, X_test_circles, y_test_circles, 'SVM con Kernel Polinómico (grado 4)')
fig.show()

# %%
# Kernel RBF
svm_rbf_circles = SVC(kernel='rbf', random_state=42)
svm_rbf_circles.fit(X_train_circles, y_train_circles)
fig = plot_decision_boundary(svm_rbf_circles, X_test_circles, y_test_circles, 'SVM con Kernel RBF')
fig.show()

# %% [markdown]
# Los resultados son peores en general. Para los kernels lineales directamente no funciona

# %%
# Blobs
X_blobs, y_blobs = make_blobs(n_samples=1000, centers=3, n_features=2, random_state=42)
X_train_blobs, X_test_blobs, y_train_blobs, y_test_blobs = train_test_split(X_blobs, y_blobs, test_size=0.3, random_state=42)

# Escalamos las características
scaler = StandardScaler()
X_train_blobs = scaler.fit_transform(X_train_blobs)
X_test_blobs = scaler.transform(X_test_blobs)

# Visualizamos los datos
fig = px.scatter(x=X_train_blobs[:, 0], y=X_train_blobs[:, 1], color=y_train_blobs.astype(str),
                 color_discrete_map={'0': 'blue', '1': 'red'},
                 title='Dataset de Entrenamiento (Blobs)',
                 labels={'x': 'Característica 1', 'y': 'Característica 2'})
fig.show()

# %%
# Regresión Logística
log_reg_blobs = LogisticRegression(random_state=42)
log_reg_blobs.fit(X_train_blobs, y_train_blobs)
fig = plot_decision_boundary(log_reg_blobs, X_test_blobs, y_test_blobs, 'Regresión Logística')
fig.show()

# %% [markdown]
# El resultado fue muy bueno, pero quiza sea overfitting

# %%
# Kernel lineal
svm_linear_blobs = SVC(kernel='linear', random_state=42)
svm_linear_blobs.fit(X_train_blobs, y_train_blobs)
fig = plot_decision_boundary(svm_linear_blobs, X_test_blobs, y_test_blobs, 'SVM con Kernel Lineal')
fig.show()

# %%
# Kernel polinómico
svm_poly_blobs = SVC(kernel='poly', degree=3, random_state=42)
svm_poly_blobs.fit(X_train_blobs, y_train_blobs)
fig = plot_decision_boundary(svm_poly_blobs, X_test_blobs, y_test_blobs, 'SVM con Kernel Polinómico (grado 3)')
fig.show()

# %%
# Kernel RBF
svm_rbf_blobs = SVC(kernel='rbf', random_state=42)
svm_rbf_blobs.fit(X_train_blobs, y_train_blobs)
fig = plot_decision_boundary(svm_rbf_blobs, X_test_blobs, y_test_blobs, 'SVM con Kernel RBF')
fig.show()

# %% [markdown]
# Los resultados fueron de un accuracy del 100% en todos los casos. probablemente porque los datos estan muy clusterizados de por si.

# %%
# Ejercicio 3
svm_1 = SVC(kernel='rbf', C=1, gamma=1)
svm_1.fit(X_train, y_train)
fig = plot_decision_boundary(svm_1, X_test, y_test, 'SVM con Kernel Lineal')
fig.show()

# %% [markdown]
# Con C = 1 y gamma = 1 se obtiene un mejor resultado.

# %%
# Pruebo con C = 100 y gamma = 1
svm_2 = SVC(kernel='rbf', C=100, gamma=1)
svm_2.fit(X_train, y_train)
fig = plot_decision_boundary(svm_2, X_test, y_test, 'SVM con Kernel Lineal')
fig.show()

# %% [markdown]
# Un poco peor

# %%
# Pruebo con C = 20 y gamma = 1
svm_3 = SVC(kernel='rbf', C=20, gamma=1)
svm_3.fit(X_train, y_train)
fig = plot_decision_boundary(svm_3, X_test, y_test, 'SVM con Kernel Lineal')
fig.show()

# %%
# Pruebo con C = 1000 y gamma = 1
svm_4 = SVC(kernel='rbf', C=1000, gamma=1)
svm_4.fit(X_train, y_train)
fig = plot_decision_boundary(svm_4, X_test, y_test, 'SVM con Kernel Lineal')
fig.show()

# %%
# Pruebo con C = 5000 y gamma = 5
svm_5 = SVC(kernel='rbf', C=5000, gamma=5)
svm_5.fit(X_train, y_train)
fig = plot_decision_boundary(svm_5, X_test, y_test, 'SVM con Kernel Lineal')
fig.show()

# %%
# Pruebo con C = 10000 y gamma = 10
svm_6 = SVC(kernel='rbf', C=10000, gamma=10)
svm_6.fit(X_train, y_train)
fig = plot_decision_boundary(svm_6, X_test, y_test, 'SVM con Kernel Lineal')
fig.show()

# %% [markdown]
# ## Conclusion
# El mejor resultado lo obtuvimos con C = 1 y gamma = 1

# %% [markdown]
# ## 6. Ejercicios Propuestos
#
# 1.  **Interpretación del Margen:** En el SVM con kernel lineal, ¿cómo podrías identificar visualmente cuáles son los vectores de soporte? (Pista: son los puntos más cercanos a la línea de separación).
#
# 2.  **Kernel Polinómico y Grado:** Modificá el grado `degree` del `SVC(kernel='poly', ...)` a 1, 2, 5 y 10. Describí cómo cambia la complejidad de la frontera de decisión y el riesgo de sobreajuste (overfitting).
#
# 3.  **El rol de `coef0`:** En el kernel polinómico, el parámetro `coef0` controla cuánto influyen los polinomios de grado alto vs. los de grado bajo. Investigá y experimentá con este parámetro. ¿Qué efecto tiene en la frontera de decisión?
#
# 4.  **Costo Computacional:** Aumentá el número de muestras en `make_moons` a 5000 y luego a 20000. Medí el tiempo de entrenamiento de la Regresión Logística y del SVM con kernel RBF usando `%%timeit` en la celda. ¿Qué observás sobre la escalabilidad de SVM?
#
# 5.  **Importancia del Escalado:** Volvé a ejecutar el notebook pero esta vez, comentá las líneas donde se usa `StandardScaler`. ¿Qué impacto tiene en el rendimiento del SVM, especialmente con kernel RBF? ¿Por qué crees que ocurre esto? (Pista: el kernel RBF depende de distancias).
#
# 6.  **Creando un Kernel Personalizado:** La clase `SVC` de Scikit-Learn permite pasar una función como kernel. Definí una función en Python que reciba dos vectores `X1` y `X2` y devuelva su producto punto (kernel lineal). Usala para entrenar un SVM: `SVC(kernel=mi_kernel_lineal)`. Obs: el parámetro debe ser una "callable" que reciba dos arrays y devuelva un escalar. ¿Cómo se compara con el SVM lineal de Scikit-Learn?
#
# 8.  **El parámetro `C` a fondo:** Creá un bucle que entrene varios SVM con kernel lineal pero con valores de `C` muy diferentes (ej. 0.01, 1, 100, 10000). Para cada uno, imprimí el número de vectores de soporte (`model.n_support_`). ¿Qué relación observás entre el valor de `C` y la cantidad de vectores de soporte?
#
# 9.  **Aplicación a un problema real:** Cargá el dataset de cáncer de mama de sklearn (`load_breast_cancer`). Como es un dataset con muchas características, no vas a poder visualizar la frontera de decisión. En su lugar, usá `GridSearchCV` de `sklearn.model_selection` para encontrar la mejor combinación de `C` y `gamma` para un SVM con kernel RBF. Compará su `accuracy` en el conjunto de test con el de una Regresión Logística.
